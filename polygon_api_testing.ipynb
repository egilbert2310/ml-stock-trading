# %%
# import
from polygon import RESTClient

# api key
api_key = "lgOPpBnVxygYIOh7SiKQapwkf6xCYHNY"

# initiating client
client = RESTClient(api_key=api_key)

# %%
trades = []
for t in client.list_trades("AAPL", "2022-04-04", limit=5):
    trades.append(t)
print(trades)
# Out:
# ---------------------------------------------------------------------------
# BadResponse                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 trades = []
# ----> 2 for t in client.list_trades("AAPL", "2022-04-04", limit=5):
#       3     trades.append(t)
#       4 print(trades)
#
# File c:\Python311\Lib\site-packages\polygon\rest\base.py:192, in BaseClient._paginate_iter(self, path, params, deserializer, result_key, options)
#     183 def _paginate_iter(
#     184     self,
#     185     path: str,
#    (...)
#     189     options: Optional[RequestOptionBuilder] = None,
#     190 ):
#     191     while True:
# --> 192         resp = self._get(
#     193             path=path,
#     194             params=params,
#     195             deserializer=deserializer,
#     196             result_key=result_key,
#     197             raw=True,
#     198             options=options,
#     199         )
#     200         decoded = self._decode(resp)
# ...

# %%
trades
# Out:
# []
